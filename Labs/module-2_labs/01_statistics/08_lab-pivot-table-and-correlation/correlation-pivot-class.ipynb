# %% [markdown]
# ### Correlation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vehicles = pd.read_csv('../../03_data-visualization/02_lab-matplotlib-seaborn/your-code/vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# ### Scatterplots

# %%
plt.scatter(vehicles['City MPG'], vehicles['Highway MPG'])

# %% [markdown]
# ### Linear Correlation between two variables

# %%
vehicles['City MPG'].corr(vehicles['Highway MPG'])
# Out:
# 0.9238555885288396

# %% [markdown]
# ### Correlation Matrix

# %%
vehicles.corr()
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.037876   0.082469
# Engine Displacement      0.037876             1.000000   0.901858
# Cylinders                0.082469             0.901858   1.000000
# Fuel Barrels/Year       -0.221084             0.789752   0.739517
# City MPG                 0.161818            -0.740317  -0.703866
# Highway MPG              0.267259            -0.715039  -0.650287
# Combined MPG             0.204751            -0.746782  -0.698648
# CO2 Emission Grams/Mile -0.222300             0.803520   0.752393
# Fuel Cost/Year          -0.091913             0.769678   0.778153
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.221084  0.161818     0.267259
# Engine Displacement               0.789752 -0.740317    -0.715039
# Cylinders                         0.739517 -0.703866    -0.650287
# ...

# %% [markdown]
# ### Correlation Heatmap

# %%
sns.heatmap(vehicles.corr())

# %%
sns.heatmap(vehicles.corr(), vmin=-1, vmax=1, annot=True, cmap="YlGnBu")

# %% [markdown]
# #### Spearman's Correlation Coefficient (Rank Correlation)

# %%
vehicles.corr(method = 'spearman')
# Out:
#                              Year  Engine Displacement  Cylinders  \
# Year                     1.000000             0.051370   0.068727
# Engine Displacement      0.051370             1.000000   0.927979
# Cylinders                0.068727             0.927979   1.000000
# Fuel Barrels/Year       -0.214857             0.827152   0.784595
# City MPG                 0.157137            -0.848167  -0.818672
# Highway MPG              0.266934            -0.754080  -0.698356
# Combined MPG             0.205080            -0.824065  -0.783362
# CO2 Emission Grams/Mile -0.215108             0.831333   0.788777
# Fuel Cost/Year          -0.091437             0.794755   0.790481
#
#                          Fuel Barrels/Year  City MPG  Highway MPG  \
# Year                             -0.214857  0.157137     0.266934
# Engine Displacement               0.827152 -0.848167    -0.754080
# Cylinders                         0.784595 -0.818672    -0.698356
# ...

# %%
sns.heatmap(vehicles.corr(method = 'spearman'), vmin=-1, vmax=1, annot=True, cmap="YlGnBu")

# %% [markdown]
# ## Pivot Tables

# %%
help(pd.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.reshape.pivot:
#
# pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All', observed=False) -> 'DataFrame'
#     Create a spreadsheet-style pivot table as a DataFrame.
#
#     The levels in the pivot table will be stored in MultiIndex objects
#     (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Parameters
#     ----------
#     data : DataFrame
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
#     columns : column, Grouper, array, or list of the previous
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"])
# Out:
#                                     CO2 Emission Grams/Mile   City MPG  \
# Vehicle Class
# Compact Cars                                     396.758088  20.570685
# Large Cars                                       484.391278  16.130310
# Midsize Cars                                     432.861095  18.950775
# Midsize Station Wagons                           432.128533  18.360577
# Midsize-Large Station Wagons                     452.981561  17.590837
# Minicompact Cars                                 443.861984  18.380363
# Minivan - 2WD                                    469.287896  16.679758
# Minivan - 4WD                                    504.595699  15.425532
# Small Pickup Trucks                              450.039261  18.416031
# Small Pickup Trucks 2WD                          454.361734  17.922693
# Small Pickup Trucks 4WD                          497.689565  16.405000
# Small Sport Utility Vehicle 2WD                  378.034759  21.147059
# ...

# %%
vehicles.pivot_table(index=["Fuel Type", "Vehicle Class"])
# Out:
#                                                          CO2 Emission Grams/Mile  \
# Fuel Type                   Vehicle Class
# CNG                         Compact Cars                              258.451954
#                             Large Cars                                450.304403
#                             Special Purpose Vehicle 2WD               470.464800
#                             Standard Pickup Trucks 2WD                629.188458
#                             Standard Pickup Trucks 4WD                787.725000
# ...                                                                          ...
# Regular                     Vans Passenger                            631.674020
#                             Vans, Cargo Type                          620.051697
#                             Vans, Passenger Type                      647.193855
# Regular Gas and Electricity Midsize Cars                              125.687500
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"], values=['Combined MPG', "City MPG"])
# Out:
#                                      City MPG  Combined MPG
# Vehicle Class
# Compact Cars                        20.570685     23.373385
# Large Cars                          16.130310     18.936854
# Midsize Cars                        18.950775     21.670441
# Midsize Station Wagons              18.360577     21.024038
# Midsize-Large Station Wagons        17.590837     19.924171
# Minicompact Cars                    18.380363     21.028053
# Minivan - 2WD                       16.679758     19.117825
# Minivan - 4WD                       15.425532     17.638298
# Small Pickup Trucks                 18.416031     20.257634
# Small Pickup Trucks 2WD             17.922693     19.997506
# Small Pickup Trucks 4WD             16.405000     18.125000
# Small Sport Utility Vehicle 2WD     21.147059     23.818182
# Small Sport Utility Vehicle 4WD     20.026316     22.421053
# Small Station Wagons                21.207148     23.839533
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"], columns=["Year"])
# Out:
#                                    CO2 Emission Grams/Mile              \
# Year                                                  1984        1985
# Vehicle Class
# Compact Cars                                           NaN  405.459677
# Large Cars                                      510.000496  513.666382
# Midsize Cars                                           NaN  470.855111
# Midsize Station Wagons                                 NaN         NaN
# Midsize-Large Station Wagons                           NaN  456.124094
# Minicompact Cars                                       NaN  422.507252
# Minivan - 2WD                                          NaN         NaN
# Minivan - 4WD                                          NaN         NaN
# Small Pickup Trucks                                    NaN  434.532471
# Small Pickup Trucks 2WD                         421.555720         NaN
# Small Pickup Trucks 4WD                         481.328898         NaN
# ...

# %%
vehicles.pivot_table(index=["Vehicle Class"], columns=["Year"], fill_value = 0)
# Out:
#                                    CO2 Emission Grams/Mile              \
# Year                                                  1984        1985
# Vehicle Class
# Compact Cars                                      0.000000  405.459677
# Large Cars                                      510.000496  513.666382
# Midsize Cars                                      0.000000  470.855111
# Midsize Station Wagons                            0.000000    0.000000
# Midsize-Large Station Wagons                      0.000000  456.124094
# Minicompact Cars                                  0.000000  422.507252
# Minivan - 2WD                                     0.000000    0.000000
# Minivan - 4WD                                     0.000000    0.000000
# Small Pickup Trucks                               0.000000  434.532471
# Small Pickup Trucks 2WD                         421.555720    0.000000
# Small Pickup Trucks 4WD                         481.328898    0.000000
# ...
